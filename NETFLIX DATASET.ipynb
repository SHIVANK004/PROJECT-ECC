# %% [markdown]
# ![Netflix.png.png](attachment:Netflix.png.png)

# %% [markdown]
# * This netflix dataset has inforamtion about the TV Shows and Movies on Netflix in 2021
# * This datasets is collected from Flexible which is a third-party Netfix search engine.

# %%
import pandas as pd
d1 = pd.read_csv('C:/Users/Hp/Desktop/New folder/PYTHON WITH DA/NETFLIX/New folder/8. Netflix Dataset.csv', header = 0 )

# %%
d1
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ## Getting some basic infromation about dataset

# %% [markdown]
# ### 1. head()

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %% [markdown]
# ### 2. Tail

# %%
d1.tail()                                                                                  #to show bottom 5 records of dataset
# Out:
#      Show_Id Category                                    Title     Director  \
# 7784   s7783    Movie                                     Zozo  Josef Fares
# 7785   s7784    Movie                                   Zubaan  Mozez Singh
# 7786   s7785    Movie                        Zulu Man in Japan          NaN
# 7787   s7786  TV Show                    Zumbo's Just Desserts          NaN
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS     Sam Dunn
#
#                                                    Cast  \
# 7784  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7785  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7786                                            Nasty C
# 7787                         Adriano Zumbo, Rachel Khoo
# 7788                                                NaN
#
#                                                 Country Release_Date Rating  \
# 7784  Sweden, Czech Republic, United Kingdom, Denmar...    19-Oct-20  TV-MA
# ...

# %% [markdown]
# ### 3. Shape

# %%
d1.shape                                                                                #to show the number of Rows and Columns
# Out:
# (7789, 12)

# %% [markdown]
# ### 4. Size

# %%
d1.size                                                                       #to show total number of elements in the dataset
# Out:
# 93468

# %% [markdown]
# ### 5. Columns

# %%
d1.columns                                                                                           #to show each Column Name
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description', 'Date_N'],
#       dtype='object')

# %% [markdown]
# ### 6. dtypes

# %%
d1.dtypes                                                                                         #to show type of each column
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# Date_N          object
# dtype: object

# %% [markdown]
# ### 7. Info()

# %%
d1.info()                                                     #to show indexes,columns,data type of each colummn, memory at once
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
#  11  Date_N        7789 non-null   object
# dtypes: object(12)
# memory usage: 730.3+ KB

# %% [markdown]
# ## Task 1. Is there any Duplicate record in this dataset? If yes, then remove the duplicate records.

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
d1[d1.duplicated()]                                                            #to check Row wise and detect the Duplicate Rows
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#      Release_Date Rating Duration                                   Type  \
# 6300     5-Apr-19  TV-MA   97 min  Dramas, Independent Movies, Thrillers
# 6622     4-Sep-20  TV-MA   94 min   Comedies, Dramas, Independent Movies
#
#                                             Description    Date_N
# 6300  When two would-be robbers accidentally kill a ...  5-Apr-19
# 6622  A disillusioned security guard transforms into...  4-Sep-20

# %%
d1.drop_duplicates()                                                                             #to remove the Duplicate Rows
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
d1.drop_duplicates(inplace = True)                                             #to Remove the Duplicate rows permanently

# %%
d1.drop_duplicates()
# Out:
#      Show_Id Category                                    Title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                Director                                               Cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %%
d1.shape
# Out:
# (7787, 12)

# %% [markdown]
# ## Task2. Is there any Null Value in any column? Show with Heat-map.

# %% [markdown]
# ### Isnull()

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
d1.isnull()                                                                                # To show Null value is present
# Out:
#       Show_Id  Category  Title  Director   Cast  Country  Release_Date  \
# 0       False     False  False      True  False    False         False
# 1       False     False  False     False  False    False         False
# 2       False     False  False     False  False    False         False
# 3       False     False  False     False  False    False         False
# 4       False     False  False     False  False    False         False
# ...       ...       ...    ...       ...    ...      ...           ...
# 7784    False     False  False     False  False    False         False
# 7785    False     False  False     False  False    False         False
# 7786    False     False  False      True  False     True         False
# 7787    False     False  False      True  False    False         False
# 7788    False     False  False     False   True    False         False
#
#       Rating  Duration   Type  Description  Date_N
# 0      False     False  False        False   False
# ...

# %%
d1.isnull().sum()                                                                     #to show Null value in each Columns
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# Date_N             0
# dtype: int64

# %% [markdown]
# ### Seaborn Liberary (heat-map)

# %%
import seaborn as sns                                                                     #to import Seaborn liberary

# %%
sns.heatmap(d1.isnull())                                                             # Using heat map to show null values count
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Q1. For 'Sinister 2' , what is the Show Id and Who is the Director of this show?

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
d1[d1['Title'].isin(['Sinister 2'])]                          #To show all records of a particular item in any column
# Out:
#      Show_Id Category       Title    Director  \
# 5634   s5634    Movie  Sinister 2  Ciarán Foy
#
#                                                    Cast  \
# 5634  Shannyn Sossamon, John Beasley, James Ransone,...
#
#                             Country Release_Date Rating Duration  \
# 5634  United States, United Kingdom    16-Oct-19      R   97 min
#
#                Type                                        Description  \
# 5634  Horror Movies  A single mother and her twin sons move into a ...
#
#          Date_N
# 5634  16-Oct-19

# %%
d1[d1['Title'].str.contains('Sinister 2')]                   #To show all records of a particular string in any column
# Out:
#      Show_Id Category       Title    Director  \
# 5634   s5634    Movie  Sinister 2  Ciarán Foy
#
#                                                    Cast  \
# 5634  Shannyn Sossamon, John Beasley, James Ransone,...
#
#                             Country Release_Date Rating Duration  \
# 5634  United States, United Kingdom    16-Oct-19      R   97 min
#
#                Type                                        Description  \
# 5634  Horror Movies  A single mother and her twin sons move into a ...
#
#          Date_N
# 5634  16-Oct-19

# %% [markdown]
# ## Q2. How many movies and series in dataset? Show with Bar graph.

# %%
d1.groupby('Category').Category.count()                     #to group all unique items f a column and show thier count
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %% [markdown]
# ### countplot()

# %%
sns.countplot(d1['Category'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %% [markdown]
# ## Q3.In which year highest number of the TV Shows & Movies were released ? Show with Bar Graph.

# %%
d1.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# Date_N          object
# dtype: object

# %% [markdown]
# ## to_datetime

# %%
d1['Date_N'] = pd.to_datetime(d1['Release_Date'])

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
d1['Date_N'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_N, dtype: int64

# %%
d1['Date_N'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %% [markdown]
# ## Q.4. Show all the Movies that were released in year 2014, 2019 and 2021.

# %% [markdown]
# ### Creating a new Column

# %%
d1['Year']= d1['Date_N'].dt.year

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Year']==2000)]
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %%
d1[(d1['Category']=='Movie') & (d1['Year']==2014)]
# Out:
#      Show_Id Category                                              Title  \
# 914     s915    Movie             Bill Burr: I'm Sorry You Feel That Way
# 1026   s1027    Movie  BoJack Horseman Christmas Special: Sabrina's C...
# 1309   s1310    Movie         Chelsea Handler: Uganda Be Kidding Me Live
# 1310   s1311    Movie                 Chelsea Peretti: One of the Greats
# 1902   s1903    Movie                                             E-Team
# 2294   s2295    Movie                        From One Second to the Next
# 2386   s2387    Movie                                          Get Santa
# 3057   s3058    Movie          Iron Man & Captain America: Heroes United
# 3966   s3967    Movie            Marvel's Iron Man & Hulk: Heroes United
# 4147   s4148    Movie                                       Mission Blue
# 4153   s4154    Movie                                               Mitt
# 4333   s4334    Movie      My Little Pony Equestria Girls: Rainbow Rocks
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Year']==2019)]
# Out:
#      Show_Id Category                     Title  \
# 7         s8    Movie                       187
# 8         s9    Movie                       706
# 13       s14    Movie                     2,215
# 15       s16    Movie                     1-Oct
# 18       s19    Movie                    15-Aug
# ...      ...      ...                       ...
# 7771   s7770    Movie  Zindagi Na Milegi Dobara
# 7775   s7774    Movie            Zoé: Panoramas
# 7776   s7775    Movie                    Zodiac
# 7780   s7779    Movie                Zombieland
# 7785   s7784    Movie                    Zubaan
#
#                                    Director  \
# 7                            Kevin Reynolds
# 8                             Shravan Kumar
# 13                      Nottapon Boonprakob
# 15                           Kunle Afolayan
# 18                       Swapnaneel Jayakar
# ...                                     ...
# 7771                            Zoya Akhtar
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Year']==2021)]
# Out:
#      Show_Id Category                        Title             Director  \
# 57       s58    Movie                   100% Halal        Jastis Arimba
# 72       s73    Movie                     17 Again          Burr Steers
# 104     s105    Movie           30 Minutes or Less      Ruben Fleischer
# 205     s206    Movie              A Monster Calls          J.A. Bayona
# 366     s367    Movie                    Al acecho  Francisco D'Eufemia
# ...      ...      ...                          ...                  ...
# 7353   s7352    Movie                      Unknown   Jaume Collet-Serra
# 7553   s7552    Movie    What Happened to Mr. Cha?         Kim Dong-kyu
# 7571   s7570    Movie  What Would Sophia Loren Do?        Ross Kauffman
# 7572   s7571    Movie  What's Eating Gilbert Grape      Lasse Hallström
# 7646   s7645    Movie                     Wish You          Sung Do-jun
#
#                                                    Cast  \
# ...

# %% [markdown]
# ## Q.5. Show only the Titles of all TV Shows and Movies that were released in India only.

# %% [markdown]
# ### Filtering

# %%
d1[(d1['Category']=='TV Show') & (d1['Country']=='India')]
# Out:
#      Show_Id Category                               Title     Director  \
# 86       s87  TV Show        21 Sarfarosh: Saragarhi 1897          NaN
# 132     s133  TV Show                           7 (Seven)  Nizar Shafi
# 340     s341  TV Show                        Agent Raghav          NaN
# 364     s365  TV Show                        Akbar Birbal          NaN
# 533     s534  TV Show                 Anjaan: Rural Myths          NaN
# ...      ...      ...                                 ...          ...
# 6249   s6249  TV Show                The Creative Indians          NaN
# 6400   s6399  TV Show  The Golden Years with Javed Akhtar          NaN
# 6469   s6468  TV Show              The House That Made Me          NaN
# 7294   s7293  TV Show                          Typewriter          NaN
# 7705   s7704  TV Show                     Yeh Meri Family          NaN
#
#                                                    Cast Country Release_Date  \
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country Release_Date  \
# ...

# %% [markdown]
# ## Q.6. Show Top 7 Directors, who gave the highest number of TV Shows & Movies to Netflix ?

# %% [markdown]
# ### Value counts()

# %%
d1['Director'].value_counts().head(7)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Jay Chapman               12
# Martin Scorsese           12
# Youssef Chahine           12
# Name: Director, dtype: int64

# %% [markdown]
# ## Q.7. Show all the Records, where "Category is Movie and Type is Suspence" or "Country is Indain"

# %% [markdown]
# ### Filtering (And, Or Operator)

# %%
d1[(d1['Category']=='Movie') & (d1['Type']=='Suspence')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Type']=='Suspence') | (d1['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 9        s10    Movie                      1920        Vikram Bhatt
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# ...      ...      ...                       ...                 ...
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7778   s7777    Movie                  Zokkomon    Satyajit Bhatkal
# 7782   s7781    Movie                       Zoo        Shlok Sharma
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country Release_Date  \
# ...

# %% [markdown]
# ## Q.8. In how many movies/shows, Tom Cruise was cast ?

# %%
### Filtering

# %%
d1[d1['Cast']=='Tom Cruise']
# Out:
# Empty DataFrame
# Columns: [Show_Id, Category, Title, Director, Cast, Country, Release_Date, Rating, Duration, Type, Description, Date_N, Year]
# Index: []

# %% [markdown]
# ### Creating a new Data Frame

# %%
d1_new=d1.dropna()                        #it drops all the rows that contains all or any missing values

# %%
d1_new.head(2)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country Release_Date  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico    23-Dec-16
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore    20-Dec-18
#
#   Rating Duration                                 Type  \
# 1  TV-MA   93 min         Dramas, International Movies
# 2      R   78 min  Horror Movies, International Movies
#
#                                          Description     Date_N    Year
# 1  After a devastating earthquake hits Mexico Cit... 2016-12-23  2016.0
# 2  When an army recruit is found dead, his fellow... 2018-12-20  2018.0

# %%
d1_new[d1_new['Cast'].str.contains('Tom Cruise')]
# Out:
#      Show_Id Category     Title              Director  \
# 3860   s3861    Movie  Magnolia  Paul Thomas Anderson
# 5071   s5071    Movie  Rain Man        Barry Levinson
#
#                                                    Cast        Country  \
# 3860  Jeremy Blackman, Tom Cruise, Melinda Dillon, A...  United States
# 5071  Dustin Hoffman, Tom Cruise, Valeria Golino, Ge...  United States
#
#      Release_Date Rating Duration                        Type  \
# 3860     1-Jan-20      R  189 min  Dramas, Independent Movies
# 5071     1-Jul-19      R  134 min      Classic Movies, Dramas
#
#                                             Description     Date_N    Year
# 3860  Through chance, human action, past history and... 2020-01-01  2020.0
# 5071  A fast-talking yuppie is forced to slow down w... 2019-07-01  2019.0

# %% [markdown]
# ## Q.9. What are the different Ratings defined by Netflix ?

# %% [markdown]
# ### nunique()

# %%
d1.Rating.nunique()
# Out:
# 14

# %% [markdown]
# #### unique

# %%
d1.Rating.unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### Q.9.1. How many Movies got the 'TV-14' rating, in India ?

# %%
d1[(d1['Category']=='Movie') & (d1['Rating']=='TV-14')].shape
# Out:
# (1272, 13)

# %%
d1[(d1['Category']=='Movie') & (d1['Rating']=='TV-14') &(d1['Country']=='India')].shape
# Out:
# (497, 13)

# %% [markdown]
# ### Q.9.2. How many TV Show got the 'R' rating, after year 2018 ?

# %%
d1[(d1['Category']=='TV Show') & (d1['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway    10-Dec-16
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration                                             Type  \
# 4497      R  1 Season  International TV Shows, TV Dramas, TV Thrillers
# 6437      R  1 Season                                         TV Shows
#
#                                             Description     Date_N    Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
d1[(d1['Category']=='TV Show') & (d1['Rating']=='R') & (d1['Year']>2018)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country Release_Date  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN    25-Apr-19
#
#      Rating  Duration      Type  \
# 6437      R  1 Season  TV Shows
#
#                                             Description     Date_N    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %% [markdown]
# ## Q.10. What is the maximum duration of a Movie/Show on Netflix ?

# %%
d1['Duration'].unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %%
d1['Duration'].dtypes
# Out:
# dtype('O')

# %% [markdown]
# ### str.split()

# %%
d1[['Minutes','Unit']] = d1['Duration'].str.split(' ', expand= True)

# %%
d1.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#   Release_Date Rating   Duration  \
# 0    14-Aug-20  TV-MA  4 Seasons
# 1    23-Dec-16  TV-MA     93 min
# 2    20-Dec-18      R     78 min
# 3    16-Nov-17  PG-13     80 min
# 4     1-Jan-20  PG-13    123 min
#
#                                                 Type  \
# ...

# %% [markdown]
# ### max()

# %%
d1['Minutes'].max()
# Out:
# '99'

# %% [markdown]
# ## Q.11. Which individual country has the Highest No. of TV Shows ?

# %%
d1_tvshow = d1[(d1['Category']=='TV Show')]

# %%
d1_tvshow.head()
# Out:
#    Show_Id Category  Title              Director  \
# 0       s1  TV Show     3%                   NaN
# 5       s6  TV Show     46           Serdar Akar
# 11     s12  TV Show   1983                   NaN
# 12     s13  TV Show   1994  Diego Enrique Osorno
# 16     s17  TV Show  9-Feb                   NaN
#
#                                                  Cast                Country  \
# 0   João Miguel, Bianca Comparato, Michel Gomes, R...                 Brazil
# 5   Erdal Beşikçioğlu, Yasemin Allen, Melis Birkan...                 Turkey
# 11  Robert Więckiewicz, Maciej Musiał, Michalina O...  Poland, United States
# 12                                                NaN                 Mexico
# 16  Shahd El Yaseen, Shaila Sabt, Hala, Hanadi Al-...                    NaN
#
#    Release_Date Rating   Duration  \
# 0     14-Aug-20  TV-MA  4 Seasons
# 5      1-Jul-17  TV-MA   1 Season
# 11    30-Nov-18  TV-MA   1 Season
# 12    17-May-19  TV-MA   1 Season
# ...

# %%
d1_tvshow.Country.value_counts()
# Out:
# United States                            705
# United Kingdom                           204
# Japan                                    157
# South Korea                              147
# India                                     71
#                                         ...
# United States, India                       1
# France, United Kingdom, United States      1
# United Kingdom, Finland, Germany           1
# Italy, United Kingdom, France              1
# Singapore, United States                   1
# Name: Country, Length: 183, dtype: int64

# %%
d1_tvshow.Country.value_counts().head(1)
# Out:
# United States    705
# Name: Country, dtype: int64

# %% [markdown]
# ## Q.12. How can we sort the dataset by Year ?

# %%
d1.sort_values(by='Year').head(2)
# Out:
#      Show_Id Category                 Title              Director  \
# 7115   s7114    Movie  To and From New York  Sorin Dan Mihalcescu
# 1765   s1766  TV Show       Dinner for Five                   NaN
#
#                                                    Cast        Country  \
# 7115  Barbara King, Shaana Diya, John Krisiukenas, Y...  United States
# 1765                                                NaN  United States
#
#      Release_Date Rating  Duration                                   Type  \
# 7115     1-Jan-08  TV-MA    81 min  Dramas, Independent Movies, Thrillers
# 1765     4-Feb-08  TV-MA  1 Season           Stand-Up Comedy & Talk Shows
#
#                                             Description     Date_N    Year  \
# 7115  While covering a story in New York City, a Sea... 2008-01-01  2008.0
# 1765  In each episode, four celebrities join host Jo... 2008-02-04  2008.0
#
#      Minutes    Unit
# 7115      81     min
# 1765       1  Season

# %%
d1.sort_values(by='Year', ascending= False) .head(2)
# Out:
#      Show_Id Category            Title                 Director  \
# 5564   s5564    Movie  Sherlock Holmes              Guy Ritchie
# 5919   s5919    Movie        Surf's Up  Ash Brannon, Chris Buck
#
#                                                    Cast  \
# 5564  Robert Downey Jr., Jude Law, Rachel McAdams, M...
# 5919  Shia LaBeouf, Jeff Bridges, Zooey Deschanel, J...
#
#                                                 Country Release_Date Rating  \
# 5564  United States, Germany, United Kingdom, Australia     1-Jan-21  PG-13
# 5919                                      United States     1-Jan-21     PG
#
#      Duration                                               Type  \
# 5564  128 min                       Action & Adventure, Comedies
# 5919   86 min  Children & Family Movies, Comedies, Sports Movies
#
#                                             Description     Date_N    Year  \
# 5564  The game is afoot for an eccentric detective w... 2021-01-01  2021.0
# ...

# %% [markdown]
# ## Q.13. Find all the instances where : Category is 'Movie' and Type is 'Dramas' or Category is 'TV Show' & Type is 'Kids' TV'.

# %% [markdown]
# ### Dramatic Movies

# %%
d1[(d1['Category']=='Movie') & (d1['Type']=='Dramas')]
# Out:
#      Show_Id Category                       Title           Director  \
# 4         s5    Movie                          21     Robert Luketic
# 7         s8    Movie                         187     Kevin Reynolds
# 170     s171    Movie                A Family Man      Mark Williams
# 232     s233    Movie  A Stoning in Fulham County      Larry Elikann
# 295     s296    Movie          Across Grace Alley      Ralph Macchio
# ...      ...      ...                         ...                ...
# 7417   s7416    Movie                      Victor  Brandon Dickerson
# 7422   s7421    Movie                     Villain   Philip Barantini
# 7449   s7448    Movie                         VS.           Ed Lilly
# 7465   s7464    Movie                   Wakefield      Robin Swicord
# 7480   s7479    Movie                   War Horse   Steven Spielberg
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Type']=='Dramas')].head(2)
# Out:
#   Show_Id Category Title        Director  \
# 4      s5    Movie    21  Robert Luketic
# 7      s8    Movie   187  Kevin Reynolds
#
#                                                 Cast        Country  \
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# 7  Samuel L. Jackson, John Heard, Kelly Rowan, Cl...  United States
#
#   Release_Date Rating Duration    Type  \
# 4     1-Jan-20  PG-13  123 min  Dramas
# 7     1-Nov-19      R  119 min  Dramas
#
#                                          Description     Date_N    Year  \
# 4  A brilliant group of students become card-coun... 2020-01-01  2020.0
# 7  After one of his high school students attacks ... 2019-11-01  2019.0
#
#   Minutes Unit
# 4     123  min
# 7     119  min

# %% [markdown]
# ### Dramatic TV Show or Kids TV

# %%
d1[(d1['Category']=='TV Show') & (d1['Type']=="Kids' TV")]
# Out:
#      Show_Id Category              Title             Director  \
# 111     s112  TV Show            44 Cats                  NaN
# 276     s277  TV Show       Abby Hatcher          Kyran Kelly
# 434     s435  TV Show        Alphablocks                  NaN
# 598     s599  TV Show  Ask the StoryBots                  NaN
# 706     s707  TV Show         Bal Ganesh  Vijay S. Bhanushali
# ...      ...      ...                ...                  ...
# 7668   s7667  TV Show      World of Winx       Iginio Straffi
# 7717   s7716  TV Show               Yoko                  NaN
# 7719   s7718  TV Show                YOM                  NaN
# 7758   s7757  TV Show                 Z4                  NaN
# 7761   s7760  TV Show          Zak Storm                  NaN
#
#                                                    Cast  \
# 111   Sarah Natochenny, Suzy Myers, Simona Berman, E...
# 276   Macy Drouin, Wyatt White, Paul Sun-Hyung Lee, ...
# ...

# %%
d1[(d1['Category']=='Movie') & (d1['Type']=='Dramas') | (d1['Category']=='TV Show') & (d1['Type']=="Kids' TV")]
# Out:
#      Show_Id Category                       Title        Director  \
# 4         s5    Movie                          21  Robert Luketic
# 7         s8    Movie                         187  Kevin Reynolds
# 111     s112  TV Show                     44 Cats             NaN
# 170     s171    Movie                A Family Man   Mark Williams
# 232     s233    Movie  A Stoning in Fulham County   Larry Elikann
# ...      ...      ...                         ...             ...
# 7668   s7667  TV Show               World of Winx  Iginio Straffi
# 7717   s7716  TV Show                        Yoko             NaN
# 7719   s7718  TV Show                         YOM             NaN
# 7758   s7757  TV Show                          Z4             NaN
# 7761   s7760  TV Show                   Zak Storm             NaN
#
#                                                    Cast  \
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 7     Samuel L. Jackson, John Heard, Kelly Rowan, Cl...
# ...
